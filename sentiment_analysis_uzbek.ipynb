# %%
import numpy as np
import pandas as pd
import re

# %% [markdown]
# ## Preprocessing stage of 3 datasets

# %%
import pandas as pd

# read txt file
uzneg = pd.read_csv('/content/UZ_negative.txt', sep='\t', header=None)
uzneg
# Out:
#                                                       0
# 0     Chromeda  biror narsa qidirib kirsang har xil ...
# 1     Telegram Messengeri odamlarni eng kop vaqtini ...
# 2     Shareit bu joyda har xil kliplar saqlanadi shu...
# 3                       ovozli pochta yuborsa bolmaydi.
# 4     odamni eng kop vaqtini oladi katta zarar yetka...
# ...                                                 ...
# 1629  Ilovadagi menyular qisqacha yozilgan tushunish...
# 1630  Buyruq berilgan vaqtni o'zia amalga oshirmaydi...
# 1631  Ishlamayotganligi haqidagi ma'lumotlarni juda ...
# 1632                     Malumotlar yaxshi yoritlmagan.
# 1633           Gaplarni mazmumini o'zgartirib yuboradi.
#
# [1634 rows x 1 columns]

# %%
# Remove duplicates, keeping the first occurrence
uzneg = uzneg.drop_duplicates(keep='first')

# Print the DataFrame without duplicates
print("\nDataFrame without duplicates:")
uzneg
# Out:
# DataFrame without duplicates:
#                                                       0
# 0     Chromeda  biror narsa qidirib kirsang har xil ...
# 1     Telegram Messengeri odamlarni eng kop vaqtini ...
# 2     Shareit bu joyda har xil kliplar saqlanadi shu...
# 3                       ovozli pochta yuborsa bolmaydi.
# 4     odamni eng kop vaqtini oladi katta zarar yetka...
# ...                                                 ...
# 1629  Ilovadagi menyular qisqacha yozilgan tushunish...
# 1630  Buyruq berilgan vaqtni o'zia amalga oshirmaydi...
# 1631  Ishlamayotganligi haqidagi ma'lumotlarni juda ...
# 1632                     Malumotlar yaxshi yoritlmagan.
# 1633           Gaplarni mazmumini o'zgartirib yuboradi.
#
# [1574 rows x 1 columns]

# %%
uzpoz = pd.read_csv('/content/UZ_positive.txt', sep='\t', header=None)
uzpoz
# Out:
#                                                       0
# 0                                                 Super
# 1                                              Axa zo'r
# 2     Barakalla! Yaxshi tashkil etilgan va ko'rsatma...
# 3     Ajoyib application Gap bolishi mumkinmas. Juda...
# 4                            Juda zo'r Ovqat jonu dilim
# ...                                                 ...
# 3037  Yaxshi xizmat, "buyurtma tarixini o'chirish" f...
# 3038  Yaxshi dastur, kun aralaridagi (masalan, har 3...
# 3039  Men dasturni yukladim, avtorizatsiya qilish bi...
# 3040  Men kechqurun taksiga buyurtma berishni xohlad...
# 3041  Interfeys tili ba'zan rus tilida chala, ingliz...
#
# [3042 rows x 1 columns]

# %%
# prompt: show me duplicates

# Identify duplicates
duplicates = uzpoz[uzpoz.duplicated(keep=False)]

# Print duplicates
print("Duplicate Rows:")
duplicates
# Out:
# Duplicate Rows:
#                         0
# 0                   Super
# 15               Gap yo'q
# 16                 Raxmat
# 50             Yomon emas
# 51            Juda ajoyib
# ...                   ...
# 2993  Juda yaxshi dastur.
# 3018               rahmat
# 3022                Super
# 3034        Yaxshi dastur
# 3035        Yaxshi dastur
#
# [936 rows x 1 columns]

# %%
#delete duplicates
uzpoz = uzpoz.drop_duplicates(keep='first')

# Print the DataFrame without duplicates
print("\nDataFrame without duplicates:")
uzpoz
# Out:
# DataFrame without duplicates:
#                                                       0
# 0                                                 Super
# 1                                              Axa zo'r
# 2     Barakalla! Yaxshi tashkil etilgan va ko'rsatma...
# 3     Ajoyib application Gap bolishi mumkinmas. Juda...
# 4                            Juda zo'r Ovqat jonu dilim
# ...                                                 ...
# 3037  Yaxshi xizmat, "buyurtma tarixini o'chirish" f...
# 3038  Yaxshi dastur, kun aralaridagi (masalan, har 3...
# 3039  Men dasturni yukladim, avtorizatsiya qilish bi...
# 3040  Men kechqurun taksiga buyurtma berishni xohlad...
# 3041  Interfeys tili ba'zan rus tilida chala, ingliz...
#
# [2224 rows x 1 columns]

# %%
# add new column to uzneg with values 0
uzneg['label'] = 0
uzneg
# Out:
#                                                       0  label
# 0     Chromeda  biror narsa qidirib kirsang har xil ...      0
# 1     Telegram Messengeri odamlarni eng kop vaqtini ...      0
# 2     Shareit bu joyda har xil kliplar saqlanadi shu...      0
# 3                       ovozli pochta yuborsa bolmaydi.      0
# 4     odamni eng kop vaqtini oladi katta zarar yetka...      0
# ...                                                 ...    ...
# 1629  Ilovadagi menyular qisqacha yozilgan tushunish...      0
# 1630  Buyruq berilgan vaqtni o'zia amalga oshirmaydi...      0
# 1631  Ishlamayotganligi haqidagi ma'lumotlarni juda ...      0
# 1632                     Malumotlar yaxshi yoritlmagan.      0
# 1633           Gaplarni mazmumini o'zgartirib yuboradi.      0
#
# [1574 rows x 2 columns]

# %%
uzpoz['label'] = 1
uzpoz
# Out:
# <ipython-input-34-e4770a08848d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uzpoz['label'] = 1
#                                                       0  label
# 0                                                 Super      1
# 1                                              Axa zo'r      1
# 2     Barakalla! Yaxshi tashkil etilgan va ko'rsatma...      1
# 3     Ajoyib application Gap bolishi mumkinmas. Juda...      1
# 4                            Juda zo'r Ovqat jonu dilim      1
# ...                                                 ...    ...
# 3037  Yaxshi xizmat, "buyurtma tarixini o'chirish" f...      1
# 3038  Yaxshi dastur, kun aralaridagi (masalan, har 3...      1
# ...

# %%
sentiment_uz = pd.read_csv('/content/sentiment_uz.csv')
sentiment_uz
# Out:
#                                                     text  label
# 0                                  uni yaxshi ko'raman\n      1
# 1      bunga qo'shimcha qilish kerak bo'lgan yuklab o...      1
# 2                                  bepul bepul qo'shiq\n      1
# 3      kyla saka ushbu o'yinlarni o'ynashni yaxshi ko...      1
# 4      juda ham ajoyib. bugungi kunga qadar men 36 ta...      1
# ...                                                  ...    ...
# 18480           karaoke ishlamayapti. o'zgarish kerak.\n      0
# 18481  juda tez donduruyor juda tez-tez muzlashadi. o...      0
# 18482  menga o'ynashga yo'l qo'ymaydi menga mehmon si...      0
# 18483  garbage app buzildi. yaxshi ishlash uchun foyd...      0
# 18484  nima bo'ladi ushodlikni qanday bildirilmoqni q...      0
#
# [18485 rows x 2 columns]

# %%
sentiment_uz['label'].value_counts()
# Out:
# label
# 0    9632
# 1    8853
# Name: count, dtype: int64

# %%
# rename column name 0 to text
uzneg.rename(columns={0: 'text'}, inplace=True)
uzneg
# Out:
#                                                    text  label
# 0     Chromeda  biror narsa qidirib kirsang har xil ...      0
# 1     Telegram Messengeri odamlarni eng kop vaqtini ...      0
# 2     Shareit bu joyda har xil kliplar saqlanadi shu...      0
# 3                       ovozli pochta yuborsa bolmaydi.      0
# 4     odamni eng kop vaqtini oladi katta zarar yetka...      0
# ...                                                 ...    ...
# 1629  Ilovadagi menyular qisqacha yozilgan tushunish...      0
# 1630  Buyruq berilgan vaqtni o'zia amalga oshirmaydi...      0
# 1631  Ishlamayotganligi haqidagi ma'lumotlarni juda ...      0
# 1632                     Malumotlar yaxshi yoritlmagan.      0
# 1633           Gaplarni mazmumini o'zgartirib yuboradi.      0
#
# [1574 rows x 2 columns]

# %%
uzpoz.rename(columns={0: 'text'}, inplace=True)
uzpoz
# Out:
# <ipython-input-66-8bbc5c4d3f0a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uzpoz.rename(columns={0: 'text'}, inplace=True)
#                                                    text  label
# 0                                                 Super      1
# 1                                              Axa zo'r      1
# 2     Barakalla! Yaxshi tashkil etilgan va ko'rsatma...      1
# 3     Ajoyib application Gap bolishi mumkinmas. Juda...      1
# 4                            Juda zo'r Ovqat jonu dilim      1
# ...                                                 ...    ...
# 3037  Yaxshi xizmat, "buyurtma tarixini o'chirish" f...      1
# 3038  Yaxshi dastur, kun aralaridagi (masalan, har 3...      1
# 3039  Men dasturni yukladim, avtorizatsiya qilish bi...      1
# ...

# %%
#add uzneg dataset to setiment
sentiment_uz = pd.concat([sentiment_uz, uzneg], ignore_index=True)
sentiment_uz
# Out:
#                                                     text  label
# 0                                  uni yaxshi ko'raman\n      1
# 1      bunga qo'shimcha qilish kerak bo'lgan yuklab o...      1
# 2                                  bepul bepul qo'shiq\n      1
# 3      kyla saka ushbu o'yinlarni o'ynashni yaxshi ko...      1
# 4      juda ham ajoyib. bugungi kunga qadar men 36 ta...      1
# ...                                                  ...    ...
# 20054  Ilovadagi menyular qisqacha yozilgan tushunish...      0
# 20055  Buyruq berilgan vaqtni o'zia amalga oshirmaydi...      0
# 20056  Ishlamayotganligi haqidagi ma'lumotlarni juda ...      0
# 20057                     Malumotlar yaxshi yoritlmagan.      0
# 20058           Gaplarni mazmumini o'zgartirib yuboradi.      0
#
# [20059 rows x 2 columns]

# %%
sentiment_uz = pd.concat([sentiment_uz, uzpoz], ignore_index=True)
sentiment_uz
# Out:
#                                                     text  label
# 0                                  uni yaxshi ko'raman\n      1
# 1      bunga qo'shimcha qilish kerak bo'lgan yuklab o...      1
# 2                                  bepul bepul qo'shiq\n      1
# 3      kyla saka ushbu o'yinlarni o'ynashni yaxshi ko...      1
# 4      juda ham ajoyib. bugungi kunga qadar men 36 ta...      1
# ...                                                  ...    ...
# 22278  Yaxshi xizmat, "buyurtma tarixini o'chirish" f...      1
# 22279  Yaxshi dastur, kun aralaridagi (masalan, har 3...      1
# 22280  Men dasturni yukladim, avtorizatsiya qilish bi...      1
# 22281  Men kechqurun taksiga buyurtma berishni xohlad...      1
# 22282  Interfeys tili ba'zan rus tilida chala, ingliz...      1
#
# [22283 rows x 2 columns]

# %%
sentiment_uz['label'].value_counts()
# Out:
# label
# 0    11206
# 1    11077
# Name: count, dtype: int64

# %%
# stats on dataset
sentiment_uz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22283 entries, 0 to 22282
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    22283 non-null  object
#  1   label   22283 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 348.3+ KB

# %%
# mix the values order
sentiment_uz = sentiment_uz.sample(frac=1).reset_index(drop=True)
sentiment_uz
# Out:
#                                                     text  label
# 0                                               A yaxshi      1
# 1                    hatto bitta ovoz ham mos kelmaydi\n      0
# 2      pliska avtobus haydovchisi men uni juda yaxshi...      1
# 3                          tanzaniyani yaxshi ko'raman\n      0
# 4      xo'sh, nima qila olaman ... menga kira olmayma...      0
# ...                                                  ...    ...
# 22278  o'yin o'ynashga imkon beradigan o'yinni juda y...      1
# 22279  sizga yoqmagan narsalaringizdan bir kun kutish...      0
# 22280  Operator bilan bog'lanishni hojati qolmabdi ha...      1
# 22281  jiddiy men hatto bu ahmoq dasturni ochishga ru...      0
# 22282  qalqonni nazorat qilgich bilan ishlamaydi bung...      0
#
# [22283 rows x 2 columns]

# %%
# download sentiment
sentiment_uz.to_csv('sentiment_uzbek.csv', index=False)

# %%
data = pd.read_csv('/content/sentiment_uzbek.csv')
data
# Out:
#                                                     text  label
# 0                                               A yaxshi      1
# 1                    hatto bitta ovoz ham mos kelmaydi\n      0
# 2      pliska avtobus haydovchisi men uni juda yaxshi...      1
# 3                          tanzaniyani yaxshi ko'raman\n      0
# 4      xo'sh, nima qila olaman ... menga kira olmayma...      0
# ...                                                  ...    ...
# 22278  o'yin o'ynashga imkon beradigan o'yinni juda y...      1
# 22279  sizga yoqmagan narsalaringizdan bir kun kutish...      0
# 22280  Operator bilan bog'lanishni hojati qolmabdi ha...      1
# 22281  jiddiy men hatto bu ahmoq dasturni ochishga ru...      0
# 22282  qalqonni nazorat qilgich bilan ishlamaydi bung...      0
#
# [22283 rows x 2 columns]

# %%
data['text'] = data['text'].apply(lambda x: x.lower())
data['text'] = data['text'].apply((lambda x: re.sub('[^a-zA-z0-9\s]', '',x)))
data
# Out:
#                                                     text  label
# 0                                               a yaxshi      1
# 1                    hatto bitta ovoz ham mos kelmaydi\n      0
# 2      pliska avtobus haydovchisi men uni juda yaxshi...      1
# 3                           tanzaniyani yaxshi koraman\n      0
# 4      xosh nima qila olaman  menga kira olmayman  me...      0
# ...                                                  ...    ...
# 22278  oyin oynashga imkon beradigan oyinni juda yaxs...      1
# 22279  sizga yoqmagan narsalaringizdan bir kun kutish...      0
# 22280  operator bilan boglanishni hojati qolmabdi ham...      1
# 22281  jiddiy men hatto bu ahmoq dasturni ochishga ru...      0
# 22282  qalqonni nazorat qilgich bilan ishlamaydi bung...      0
#
# [22283 rows x 2 columns]

# %%
data['label'].value_counts()
# Out:
# label
# 0    11206
# 1    11077
# Name: count, dtype: int64

# %% [markdown]
# ## Training part

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, SpatialDropout1D

# %%
max_features = 2000
tokenizer = Tokenizer(num_words=max_features, split=' ')
tokenizer.fit_on_texts(data['text'].values)
X = tokenizer.texts_to_sequences(data['text'].values)
X = pad_sequences(X)

# %%
X
# Out:
# array([[   0,    0,    0, ...,   13, 1147,  325],
#        [   0,    0,    0, ...,   41,  285,  114],
#        [   0,    0,    0, ...,    0,    0,  511],
#        ...,
#        [   0,    0,    0, ...,    7,    2,  158],
#        [   0,    0,    0, ...,    0,   53,   25],
#        [   0,    0,    0, ...,   14,   12,   43]], dtype=int32)

# %%
embed_dim = 128
lstm_out = 196

model = Sequential()

model.add(Embedding(max_features, embed_dim, input_length=X.shape[1]))
model.add(SpatialDropout1D(0.4))
model.add(LSTM(lstm_out, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(2, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.build(input_shape=(None, X.shape[1]))
print(model.summary())
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_5 (Embedding)              │ (None, 44, 128)             │         256,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ spatial_dropout1d_5                  │ (None, 44, 128)             │               0 │
# │ (SpatialDropout1D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
Y = pd.get_dummies(data['label']).values
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=12)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (17826, 44) (17826, 2)
# (4457, 44) (4457, 2)

# %%
model.fit(X_train, Y_train, epochs=5, batch_size=64, verbose=2)
# Out:
# Epoch 1/5
# 279/279 - 39s - 141ms/step - accuracy: 0.9309 - loss: 0.1689
# Epoch 2/5
# 279/279 - 41s - 148ms/step - accuracy: 0.9340 - loss: 0.1615
# Epoch 3/5
# 279/279 - 41s - 146ms/step - accuracy: 0.9391 - loss: 0.1486
# Epoch 4/5
# 279/279 - 41s - 146ms/step - accuracy: 0.9401 - loss: 0.1466
# Epoch 5/5
# 279/279 - 40s - 143ms/step - accuracy: 0.9442 - loss: 0.1364

# %%
score, acc = model.evaluate(X_test, Y_test, verbose=2, batch_size=64)
print("Score: %.2f" % (score))
print("Accuracy: %.2f" % (acc))
# Out:
# 70/70 - 2s - 24ms/step - accuracy: 0.8443 - loss: 0.5383
# Score: 0.54
# Accuracy: 0.84

# %%
model.save('sentiment_analysis_uzbek.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
def predict_sentiment(text, model = model, tokenizer = tokenizer):
    #text = text.lower()
    text = tokenizer.texts_to_sequences([text])
    text = pad_sequences(text, maxlen=X.shape[1])
    sentiment = model.predict(text)[0]
    if np.argmax(sentiment) == 0:
        return "Negative"
    elif np.argmax(sentiment) == 1:
        return "Positive"

# %%
text = ["unchali yomon emas"]
predict_sentiment(text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 'Positive'

# %%
# !pip install gradio

# %%
import gradio as gr

demo = gr.Interface(fn=predict_sentiment,
                    inputs=gr.Textbox(lines=2, placeholder="Fikringizni shu yerga yozing..."),
                    outputs="text")
demo.launch(share=True, debug=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://2b582a0eb2355dc762.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://2b582a0eb2355dc762.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://2b582a0eb2355dc762.gradio.live
